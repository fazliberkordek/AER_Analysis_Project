# %% [markdown]
# <a href="https://colab.research.google.com/github/fazliberkordek/AER_Analysis_Project/blob/main/AER_Analysis_Projects_ipynb_adl%C4%B1_dosyan%C4%B1n_kopyas%C4%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Fazlı Berk ÖRDEK
#
#
#  PYTHON PROGRAMLAMA DİLİ KULLARAK YAŞ,DUYGU,CİNSİYET ANALİZİ. (GERÇEK ZAMANLI KAMERA DESTEKLİ)

# %% [markdown]
# Öncelikle Gerekli Kütüphaneleri çağırıyoruz.

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# !pip show tensorflow
# !pip install --upgrade tensorflow
# !pip install deepface
import numpy as np
# Out:
# Name: tensorflow
# Version: 2.4.1
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /usr/local/lib/python3.7/dist-packages
# Requires: flatbuffers, h5py, keras-preprocessing, numpy, absl-py, astunparse, protobuf, six, termcolor, wrapt, gast, google-pasta, tensorboard, grpcio, wheel, tensorflow-estimator, opt-einsum, typing-extensions
# Required-by: fancyimpute
# Requirement already up-to-date: tensorflow in /usr/local/lib/python3.7/dist-packages (2.4.1)
# ...
#      |████████████████████████████████| 61kB 3.4MB/s
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 2.3MB 7.6MB/s
# ...

# %% [markdown]
# Daha sonra gerekli olan kütüphaneleri  import komutuyla programa  ekliyoruz.

# %%
import cv2
import numpy as np
from deepface import DeepFace

# %%
img = cv2.imread('elon-musk-image.jpg')
img2 = cv2.imread('elon-musk-image.jpg')

# %% [markdown]
# Programımızın bulunduğu  Uygulama_Tasarım.py klasörünün içerisine  üerinde işlem yapacağımızı resimi jpg veya png formatında ekliyoruz ve programımıza çağırıyoruz.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Tabi bilgisayarımızın fotoğrafı tanımlayabilmöesi için onu matrislerden oluşacak şekilde formatlıyoruz.

# %%
cv2.imread("/content/gdrive/MyDrive/ColabNotebooks/DeepFace/AER_Analysis/elon-musk-image.jpg")
plt.imshow(cv2.imread("/content/gdrive/MyDrive/ColabNotebooks/DeepFace/AER_Analysis/elon-musk-image.jpg"))

# %%
img = plt.imread("/content/gdrive/MyDrive/ColabNotebooks/DeepFace/AER_Analysis/elon-musk-image.jpg")
plt.imshow(img)

# %% [markdown]
# çağırılan resim görüldüğü gibi standart olarak BGR renk şemasında.

# %% [markdown]
# Resimi orijinal renklerine döndürelim.

# %% [markdown]
# Şimdi ise kişinin yaş,cinsiyet ve duygu analizini yapmak istediğimiz parametreleri tahminler  olarak görüntüleyeceğiz.

# %%
from skimage import io
img2 = io.imread("/content/gdrive/MyDrive/ColabNotebooks/DeepFace/AER_Analysis/elon-musk-image.jpg")
plt.imshow(cv2.imread("/content/gdrive/MyDrive/ColabNotebooks/DeepFace/AER_Analysis/elon-musk-image.jpg"))

# %%
tahminler = DeepFace.analyze(img2)
# Out:
# facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://drive.google.com/uc?id=13iUHHP3SlNg53qSuQZDdHDSDNdBP9nwy
# To: /root/.deepface/weights/facial_expression_model_weights.zip
# 5.54MB [00:00, 38.7MB/s]
# age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://drive.google.com/uc?id=1YCox_4kJ-BYeXq27uUbasu--yz28zUMV
# To: /root/.deepface/weights/age_model_weights.h5
# 539MB [00:05, 99.3MB/s]
# gender_model_weights.h5 will be downloaded...
# Downloading...
# From: https://drive.google.com/uc?id=1wUXRVlbsni2FN9-jkS_f4UTUrm1bRLyk
# To: /root/.deepface/weights/gender_model_weights.h5
# 537MB [00:11, 45.4MB/s]
# race_model_single_batch.h5 will be downloaded...
# Downloading...
# From: https://drive.google.com/uc?id=1nz-WDhghGQBC4biwShQ9kYjvQMpO6smj
# To: /root/.deepface/weights/race_model_single_batch.zip
# 511MB [00:04, 112MB/s]
# Action: race: 100%|██████████| 4/4 [00:07<00:00,  1.90s/it]

# %% [markdown]
# Hadi bakalım tahminlerimiz ne sonuç verecek:

# %%
tahminler
# Out:
# {'age': 35,
#  'dominant_emotion': 'happy',
#  'dominant_race': 'white',
#  'emotion': {'angry': 0.17573266522958875,
#   'disgust': 0.0006454712547565578,
#   'fear': 3.95803265273571,
#   'happy': 72.8178858757019,
#   'neutral': 16.3198322057724,
#   'sad': 6.439478695392609,
#   'surprise': 0.2883938839659095},
#  'gender': 'Man',
#  'race': {'asian': 0.004577197887530238,
#   'black': 1.690055556318367e-05,
#   'indian': 0.0008523953109602909,
#   'latino hispanic': 3.4127289600806807,
#   'middle eastern': 0.30411418477381374,
#   'white': 96.27770759330437}}

# %%
print("Yaş : {}\nCinsiyet: {}\nDuygu: {}\nMilliyet : {}".format(tahminler['age'],tahminler['gender'],tahminler['dominant_emotion'],tahminler['dominant_race']))
# Out:
# Yaş : 35
# Cinsiyet: Man
# Duygu: happy
# Milliyet : white
